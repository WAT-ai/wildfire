# %%
import pandas as pd
import os

# %%
filtered_data_file_path = "../data/processing/weather-stations/kelowna/kelowna_stations.csv"
filtered_df = pd.read_csv(filtered_data_file_path)

filtered_df
# Out:
#      Network ID Network Name              Native ID  Station ID  \
# 0             1           EC                1120090         231
# 1             1           EC                1120475         232
# 2             1           EC                1123977         233
# 3             1           EC                1124260         235
# 4             1           EC                1125703         237
# ..          ...          ...                    ...         ...
# 512          12    FLNRO-WMB                   1392       12523
# 513           9      ENV-AQN       Kelowna KLO Road       12554
# 514           9      ENV-AQN  Vernon Science Centre       12585
# 515          14      ENV-ASP                  2F10P       12954
# 516          14      ENV-ASP                 1F04P2       13008
#
#             Station Name  History ID Province   Longitude   Latitude  \
# 0                   ADRA         634       BC -119.583333  49.733333
# 1    ARMSTRONG GRANDVIEW         635       BC -119.283333  50.400000
# 2        KELOWNA BYLANDS         636       BC -119.583333  49.866667
# 3                 KIRTON         638       BC -119.950000  49.666667
# 4       OKANAGAN MISSION         640       BC -119.516667  49.800000
# ..                   ...         ...      ...         ...        ...
# 512          MCNULTY EXT       14545       BC -120.173222  49.555694
# 513                  NaN       14576       BC -119.467461  49.862119
# 514                  NaN       14607       BC -119.270723  50.260617
# 515                  NaN       14886       BC -119.062100  50.371400
# 516                  NaN       14940       BC -118.926800  50.652900
#
#      Elevation (m) Record Start  Record End     Obs Freq  \
# 0           1003.0   1928-09-01  1953-08-31        Daily
# 1            503.0   1959-03-27  1960-06-30        Daily
# 2            480.0   1994-05-01  1995-10-31        Daily
# 3            884.0   1928-09-01  1962-04-30        Daily
# 4            408.0   1970-11-15  2001-01-01        Daily
# ..             ...          ...         ...          ...
# 512         1595.0   2020-06-15  2024-01-13  Unspecified
# 513            NaN   2020-07-27  2020-11-22  Unspecified
# 514            NaN   2020-07-27  2020-11-22  Unspecified
# 515            NaN   2021-03-18  2024-01-11  Unspecified
# 516            NaN   2021-12-08  2023-10-09  Unspecified
#
#                                              Variables
# 0    Precipitation Amount|Rainfall Amount|Snowfall ...
# 1    Precipitation Amount|Rainfall Amount|Snowfall ...
# 2    Precipitation Amount|Rainfall Amount|Snowfall ...
# 3    Precipitation Amount|Rainfall Amount|Snowfall ...
# 4    Precipitation Amount|Precipitation Climatology...
# ..                                                 ...
# 512  Precipitation Amount|Relative Humidity (Mean)|...
# 513   Relative Humidity (Point)|Wind Direction (Point)
# 514   Relative Humidity (Point)|Wind Direction (Point)
# 515  Cumulative Precipitation|Precipitation 1hr|Pre...
# 516  Cumulative Precipitation|Precipitation 1hr|Pre...
#
# [517 rows x 14 columns]

# %%
my_filter = ['ONE_DAY_PRECIPITATION', 'ONE_DAY_RAIN', 'MIN_TEMP', 'ONE_DAY_SNOW', 'time', 'MAX_TEMP']

for curr_year in range(2012, 2024):
    yearly_dataframes = []

    for index, row in filtered_df.iterrows():
        network_name = row['Network Name']
        native_id = row['Native ID']
        
        file_path = f'../data/raw/weather/{curr_year}/{network_name}/{native_id}.csv'

        if os.path.exists(file_path):
            temp_df = pd.read_csv(file_path, skiprows=1)
            
            yearly_dataframes.append(temp_df)

    if yearly_dataframes:
        combined_df = pd.concat(yearly_dataframes, ignore_index=True)
        combined_df.columns = [i.lstrip() for i in combined_df.columns]
        existing_columns = [c for c in my_filter if c in combined_df.columns]
        combined_df = combined_df[existing_columns]
#         print(combined_df.columns)
        combined_csv_path = f'combined_data_{curr_year}.csv'
        combined_df.to_csv(combined_csv_path, index=False)
