# %%
import pandas as pd
import os
from pathlib import Path

base_dir = str(Path().absolute())
coarse_area = "/data/weather-stations/kelowna/kelowna_stations.csv"


metadata_file_path = base_dir + coarse_area
coarse_df = pd.read_csv(metadata_file_path)

coarse_df
# Out:
#      Network ID Network Name              Native ID  Station ID
# 0             1           EC                1120090         231  \
# 1             1           EC                1120475         232
# 2             1           EC                1123977         233
# 3             1           EC                1124260         235
# 4             1           EC                1125703         237
# ..          ...          ...                    ...         ...
# 512          12    FLNRO-WMB                   1392       12523
# 513           9      ENV-AQN       Kelowna KLO Road       12554
# 514           9      ENV-AQN  Vernon Science Centre       12585
# 515          14      ENV-ASP                  2F10P       12954
# 516          14      ENV-ASP                 1F04P2       13008
#
#             Station Name  History ID Province   Longitude   Latitude
# 0                   ADRA         634       BC -119.583333  49.733333  \
# 1    ARMSTRONG GRANDVIEW         635       BC -119.283333  50.400000
# 2        KELOWNA BYLANDS         636       BC -119.583333  49.866667
# 3                 KIRTON         638       BC -119.950000  49.666667
# 4       OKANAGAN MISSION         640       BC -119.516667  49.800000
# ..                   ...         ...      ...         ...        ...
# 512          MCNULTY EXT       14545       BC -120.173222  49.555694
# 513                  NaN       14576       BC -119.467461  49.862119
# 514                  NaN       14607       BC -119.270723  50.260617
# 515                  NaN       14886       BC -119.062100  50.371400
# 516                  NaN       14940       BC -118.926800  50.652900
#
#      Elevation (m) Record Start  Record End     Obs Freq
# 0           1003.0   1928-09-01  1953-08-31        Daily  \
# 1            503.0   1959-03-27  1960-06-30        Daily
# 2            480.0   1994-05-01  1995-10-31        Daily
# 3            884.0   1928-09-01  1962-04-30        Daily
# 4            408.0   1970-11-15  2001-01-01        Daily
# ..             ...          ...         ...          ...
# 512         1595.0   2020-06-15  2024-01-13  Unspecified
# 513            NaN   2020-07-27  2020-11-22  Unspecified
# 514            NaN   2020-07-27  2020-11-22  Unspecified
# 515            NaN   2021-03-18  2024-01-11  Unspecified
# 516            NaN   2021-12-08  2023-10-09  Unspecified
#
#                                              Variables
# 0    Precipitation Amount|Rainfall Amount|Snowfall ...
# 1    Precipitation Amount|Rainfall Amount|Snowfall ...
# 2    Precipitation Amount|Rainfall Amount|Snowfall ...
# 3    Precipitation Amount|Rainfall Amount|Snowfall ...
# 4    Precipitation Amount|Precipitation Climatology...
# ..                                                 ...
# 512  Precipitation Amount|Relative Humidity (Mean)|...
# 513   Relative Humidity (Point)|Wind Direction (Point)
# 514   Relative Humidity (Point)|Wind Direction (Point)
# 515  Cumulative Precipitation|Precipitation 1hr|Pre...
# 516  Cumulative Precipitation|Precipitation 1hr|Pre...
#
# [517 rows x 14 columns]

# %%
#calculate size of splits

splits = 12

min_latitude = 49.497
max_latitude = 51.0

w = max_latitude - min_latitude

min_longitude = -120.331 
max_longitude = -118.191

h = max_longitude - min_longitude

print(w)

print(h)

fine_width = w/splits

fine_height = h/splits

print(fine_width)
print(fine_height)
# Out:
# 1.5030000000000001
# 2.1400000000000006
# 0.12525
# 0.17833333333333337

# %%
# fine_df = split up 517 stations into manageable chunks
min_latitude = 49.497
max_latitude = 51.0

min_longitude = -120.331 
max_longitude = -118.191


fine_w = 0.125

fine_h = 0.178

splits = 12

for i in range(splits):
    # Create boolean masks for latitude and longitude conditions
    latitude_mask = (coarse_df['Latitude'] >= min_latitude)  & (coarse_df['Latitude'] <= min_latitude + fine_w) & (coarse_df['Latitude'] <= max_latitude)
    longitude_mask = (coarse_df['Longitude'] >= min_longitude) & (coarse_df['Longitude'] <= min_longitude + fine_h ) & (coarse_df['Longitude'] <= max_longitude)
    # Apply the masks to filter the DataFrame
    filtered_df = coarse_df[latitude_mask & longitude_mask]

    print(filtered_df)

    min_latitude += fine_w
    min_longitude += fine_h
    filtered_df.to_csv("fine_area"+ str(i) +".csv", index=False)
# Out:
#      Network ID Network Name Native ID  Station ID       Station Name
# 486          12    FLNRO-WMB      1180       11000  ZZ RED CREEK TEMP  \
# 512          12    FLNRO-WMB      1392       12523        MCNULTY EXT
#
#      History ID Province   Longitude   Latitude  Elevation (m) Record Start
# 486       13168       BC -120.220833  49.529167         1400.0   2014-06-25  \
# 512       14545       BC -120.173222  49.555694         1595.0   2020-06-15
#
#      Record End     Obs Freq
# 486  2018-09-11  Unspecified  \
# 512  2024-01-13  Unspecified
#
#                                              Variables
# 486  Precipitation Amount|Relative Humidity (Mean)|...
# 512  Precipitation Amount|Relative Humidity (Mean)|...
#      Network ID Network Name Native ID  Station ID           Station Name
# 229          17         ARDA    112048        4864                 THIRSK  \
# 230          17         ARDA    112049        4865                 KIRTON
# 488          12    FLNRO-WMB      1212       11412           ZZ KIRTON TS
# 493          12    FLNRO-WMB      1254       12017       ZZ LOST CHAIN TS
# 498          12    FLNRO-WMB      1285       12046  ZZ KATHLEEN LAKE TEMP
#
#      History ID Province   Longitude   Latitude  Elevation (m) Record Start
# 229        6544       BC -120.055833  49.711667         1013.0   1971-04-27  \
# 230        6545       BC -119.977500  49.689167          945.0   1971-04-27
# 488       13473       BC -120.023333  49.637783         1491.0   2015-06-02
# 493       14074       BC -120.066667  49.648617         1633.0   2015-08-06
# 498       14103       BC -120.066950  49.738333         1397.0   2017-05-31
#
#      Record End     Obs Freq
# 229  1972-09-28    Irregular  \
# 230  1972-09-28    Irregular
# 488  2015-10-06  Unspecified
# 493  2016-10-12  Unspecified
# 498  2017-10-20  Unspecified
#
#                                              Variables
# 229  Precipitation (Cumulative)|Surface Snow Depth ...
# 230  Precipitation (Cumulative)|Surface Snow Depth ...
# 488  Precipitation Amount|Relative Humidity (Mean)|...
# 493  Precipitation Amount|Relative Humidity (Mean)|...
# 498  Precipitation Amount|Relative Humidity (Mean)|...
#      Network ID Network Name Native ID  Station ID            Station Name
# 5             1           EC   1126080         241  PEACHLAND TREPANIER CR  \
# 254          17         ARDA    112171        4964                  PIGEON
# 507           2        MoTIe     29094       12471             Brenda Mine
#
#      History ID Province   Longitude   Latitude  Elevation (m) Record Start
# 5           644       BC -119.833333  49.783333          549.0   1924-10-01  \
# 254        6644       BC -119.837222  49.795000          907.0   1971-03-31
# 507       14493       BC -119.936860  49.869730         1270.0   2019-11-21
#
#      Record End     Obs Freq
# 5    1943-05-31        Daily  \
# 254  1972-10-29        Daily
# 507  2024-01-14  Unspecified
#
#                                              Variables
# 5    Precipitation Amount|Rainfall Amount|Snowfall ...
# 254  Precipitation (Cumulative)|Surface Snow Depth ...
# 507  Dew Point Temperature|Precipitation 24hr|Preci...
#      Network ID Network Name Native ID  Station ID         Station Name
# 169          12    FLNRO-WMB       742        2190          ZZ LAMBLY 2  \
# 170          12    FLNRO-WMB       743        2191          ZZ LAMBLY 3
# 171          12    FLNRO-WMB       745        2193  ZZ LAMBLY[DEMO2000]
#
#      History ID Province  Longitude  Latitude  Elevation (m) Record Start
# 169        2593       BC  -119.7076   49.9596         1150.0   2001-06-26  \
# 170        2594       BC  -119.7096   49.9590         1150.0   2001-06-26
# 171        2596       BC  -119.7170   49.9670         1100.0   2000-06-09
#
#      Record End Obs Freq                                          Variables
# 169  2001-10-17   Hourly  Precipitation Amount|Relative Humidity (Mean)|...
# 170  2001-10-17   Hourly  Precipitation Amount|Relative Humidity (Mean)|...
# 171  2002-10-22   Hourly  Precipitation Amount|Precipitation Climatology...
#      Network ID Network Name Native ID  Station ID Station Name  History ID
# 71            1           EC   1128983        1101   WOODS LAKE        1504  \
# 269          17         ARDA    112209        4980       LAMBLY        6660
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 71        BC -119.450000  50.050000          405.0   1915-06-01  1939-01-31  \
# 269       BC -119.616667  50.013333          972.0   1971-05-28  1972-09-28
#
#       Obs Freq                                          Variables
# 71       Daily  Precipitation Amount|Rainfall Amount|Snowfall ...
# 269  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
#      Network ID Network Name Native ID  Station ID       Station Name
# 60            1           EC   1128551        1090             VERNON  \
# 67            1           EC   1128585        1097   VERNON SOUTHWEST
# 138          12    FLNRO-WMB       289        1839        ZZ KAL LAKE
# 152          12    FLNRO-WMB       341        1887      ZZ KAL LK. II
# 201           2        MoTIe     23097        2690  Kalamalka Lookout
# 279          17         ARDA    112231        4990        RATTLESNAKE
# 280          17         ARDA    112232        4991          KALAMALKA
#
#      History ID Province   Longitude   Latitude  Elevation (m) Record Start
# 60         1493       BC -119.283333  50.233333          556.0   1971-10-01  \
# 67         1500       BC -119.366667  50.233333          370.0   1966-04-01
# 138        2242       BC -119.300000  50.200000            4.0   1986-04-01
# 152        2290       BC -119.276700  50.236700          457.0   1987-07-29
# 201        3433       BC -119.306070  50.211200          570.0   1998-12-30
# 279        6670       BC -119.386667  50.126667          425.0   1971-04-28
# 280        6671       BC -119.344167  50.187500          482.0   1971-06-28
#
#      Record End   Obs Freq                                          Variables
# 60   2001-01-01      Daily  Precipitation Amount|Precipitation Climatology...
# 67   2001-01-01      Daily  Precipitation Amount|Precipitation Climatology...
# 138  1990-07-10      Daily  Precipitation Amount|Relative Humidity (Mean)|...
# 152  2001-01-01     Hourly  Precipitation Amount|Precipitation Climatology...
# 201  2024-01-14     Hourly  Air Pressure|Air Pressure (Point)|Dew Point Te...
# 279  1972-09-29  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
# 280  1972-09-29  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
#      Network ID Network Name Native ID  Station ID Station Name  History ID
# 62            1           EC   1128554        1092    VERNON BX        1495  \
# 221          17         ARDA    112025        4841        SPOOR        6521
# 282          17         ARDA    112242        4994    SWAN LAKE        6674
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 62        BC -119.216667  50.283333          518.0   1960-04-15  1966-03-31  \
# 221       BC -119.236111  50.295833          521.0   1975-06-24  1975-08-26
# 282       BC -119.239167  50.295000          500.0   1971-04-07  1972-10-29
#
#     Obs Freq                                          Variables
# 62     Daily  Precipitation Amount|Rainfall Amount|Snowfall ...
# 221    Daily              Temperature (Max.)|Temperature (Min.)
# 282    Daily  Surface Snow Depth (Point)|Temperature (Max.)|...
#      Network ID Network Name Native ID  Station ID Station Name  History ID
# 332          17         ARDA    116116        5601      DEAFIES        7283  \
# 333          17         ARDA    116117        5602        VANCE        7284
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 332       BC -118.934167  50.387500          747.0   1971-05-30  1972-09-29  \
# 333       BC -118.966667  50.455278          660.0   1971-05-30  1972-07-31
#
#       Obs Freq                   Variables
# 332  Irregular  Precipitation (Cumulative)
# 333  Irregular  Precipitation (Cumulative)
#      Network ID Network Name Native ID  Station ID Station Name  History ID
# 336          17         ARDA    116122        5605  ASHTON 4900        7287  \
# 337          17         ARDA    116123        5606   KINGFISHER        7288
# 338          17         ARDA    116124        5607        HUPEL        7289
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 336       BC -118.900833  50.611667         1513.0   1971-04-05  1971-07-30  \
# 337       BC -118.870833  50.589167          393.0   1971-05-30  1972-08-31
# 338       BC -118.766667  50.617500          497.0   1971-05-30  1972-09-29
#
#       Obs Freq                                          Variables
# 336      Daily  Precipitation (Cumulative)|Temperature (Max.)|...
# 337  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
# 338  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
#      Network ID Network Name Native ID  Station ID   Station Name  History ID
# 158          12    FLNRO-WMB       354        1899  ZZ YARD CREEK        2302  \
# 340          17         ARDA    116126        5609          NOISY        7291
# 495          12    FLNRO-WMB      1255       12020  ZZ ICE BOX TS       14077
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 158       BC -118.700000  50.700000           13.0   1979-06-04  2000-10-01  \
# 340       BC -118.703333  50.738333          724.0   1971-05-30  1972-09-29
# 495       BC -118.640833  50.691950          756.0   2016-06-03  2016-10-12
#
#         Obs Freq                                          Variables
# 158        Daily  Precipitation Amount|Precipitation Climatology...
# 340    Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
# 495  Unspecified  Precipitation Amount|Relative Humidity (Mean)|...
# Empty DataFrame
# Columns: [Network ID, Network Name, Native ID, Station ID, Station Name, History ID, Province, Longitude, Latitude, Elevation (m), Record Start, Record End, Obs Freq, Variables]
# Index: []
#      Network ID Network Name Native ID  Station ID Station Name  History ID
# 313          17         ARDA    114083        5138    MONTANA 2        6818  \
#
#     Province   Longitude   Latitude  Elevation (m) Record Start  Record End
# 313       BC -118.273333  50.946667          640.0   1969-05-29  1971-03-30  \
#
#       Obs Freq                                          Variables
# 313  Irregular  Precipitation (Cumulative)|Surface Snow Depth ...
